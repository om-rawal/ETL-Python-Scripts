# %%
# using the adventure works database ->"Data\AdvWorksData.xlsx"

# %%
# !pip install matplotlib numpy pandas scipy seaborn
# Out:
# Requirement already satisfied: matplotlib in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (3.5.3)
# Requirement already satisfied: numpy in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (1.23.2)
# Requirement already satisfied: pandas in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (1.4.3)
# Collecting scipy
#   Downloading scipy-1.9.1-cp310-cp310-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 3.6 MB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      -------------------------------------- 292.8/292.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (4.37.1)
# Requirement already satisfied: packaging>=20.0 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pytz>=2020.1 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in d:\code\etl\etl-python-scripts\etl_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.9.1 seaborn-0.11.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from scipy.stats import norm
from scipy.stats import ttest_ind
import statistics
from IPython.display import Image
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df=pd.read_excel('Data\AdvWorksData.xlsx')

# %%
df.head()
# Out:
#   productcategory productsubcategory                product   saleterritory  \
# 0        Clothing               Caps           AWC Logo Cap  United Kingdom
# 1     Accessories              Locks             Cable Lock  United Kingdom
# 2        Clothing             Gloves  Full-Finger Gloves, L  United Kingdom
# 3        Clothing             Gloves  Full-Finger Gloves, L  United Kingdom
# 4        Clothing             Gloves  Full-Finger Gloves, M  United Kingdom
#
#           Country    City     Sate      Customer     Employee  OrderCount  \
# 0  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 1  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 2  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 3  United Kingdom  London  England  Linda Martin  Amy Alberts           1
# 4  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
#
#    OrderDate  StandardCost  UnitPrice  UnitPriceDiscount  Discount  ListPrice  \
# 0 2012-06-30        6.9223     5.0136               0.02    1.4038     8.6442
# 1 2012-06-30       10.3125    15.0000               0.00    0.0000    25.0000
# 2 2012-06-30       15.6709    22.7940               0.00    0.0000    37.9900
# 3 2012-06-30       15.6709    20.8945               0.05   16.7156    37.9900
# 4 2012-06-30       15.6709    22.7940               0.00    0.0000    37.9900
#
#    SaleswithStandard   NetSales  OrderQuantity       Sales
# 0            96.9122 -28.125608             14   68.786592
# 1            61.8750  28.125000              6   90.000000
# 2           125.3672  56.984800              8  182.352000
# 3           250.7344  66.862000             16  317.596400
# 4           109.6963  49.861700              7  159.558000

# %%
df.tail()
# Out:
#       productcategory productsubcategory                     product  \
# 60875        Clothing             Shorts  Women's Mountain Shorts, L
# 60876        Clothing             Shorts  Women's Mountain Shorts, L
# 60877        Clothing             Shorts  Women's Mountain Shorts, M
# 60878        Clothing             Shorts  Women's Mountain Shorts, S
# 60879        Clothing             Shorts  Women's Mountain Shorts, S
#
#       saleterritory        Country     City     Sate          Customer  \
# 60875     Southeast  United States  Decatur  Georgia        Pamela Cox
# 60876     Southeast  United States    Miami  Florida  Stephanie Conroy
# 60877     Southeast  United States  Decatur  Georgia        Pamela Cox
# 60878     Southeast  United States  Decatur  Georgia        Pamela Cox
# 60879     Southeast  United States    Miami  Florida  Stephanie Conroy
#
#           Employee  OrderCount  OrderDate  StandardCost  UnitPrice  \
# 60875  Tsvi Reiter           1 2014-05-01       26.1763     41.994
# 60876  Tsvi Reiter           1 2014-05-01       26.1763     41.994
# 60877  Tsvi Reiter           1 2014-05-01       26.1763     41.994
# 60878  Tsvi Reiter           1 2014-05-01       26.1763     41.994
# 60879  Tsvi Reiter           1 2014-05-01       26.1763     41.994
#
#        UnitPriceDiscount  Discount  ListPrice  SaleswithStandard  NetSales  \
# 60875                0.0       0.0      69.99           209.4104  126.5416
# 60876                0.0       0.0      69.99           157.0578   94.9062
# 60877                0.0       0.0      69.99            78.5289   47.4531
# 60878                0.0       0.0      69.99           130.8815   79.0885
# 60879                0.0       0.0      69.99            78.5289   47.4531
#
#        OrderQuantity    Sales
# 60875              8  335.952
# 60876              6  251.964
# 60877              3  125.982
# 60878              5  209.970
# 60879              3  125.982

# %%
df.dtypes
# Out:
# productcategory               object
# productsubcategory            object
# product                       object
# saleterritory                 object
# Country                       object
# City                          object
# Sate                          object
# Customer                      object
# Employee                      object
# OrderCount                     int64
# OrderDate             datetime64[ns]
# StandardCost                 float64
# UnitPrice                    float64
# UnitPriceDiscount            float64
# Discount                     float64
# ListPrice                    float64
# SaleswithStandard            float64
# NetSales                     float64
# OrderQuantity                  int64
# Sales                        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['productcategory', 'productsubcategory', 'product', 'saleterritory',
#        'Country', 'City', 'Sate', 'Customer', 'Employee', 'OrderCount',
#        'OrderDate', 'StandardCost', 'UnitPrice', 'UnitPriceDiscount',
#        'Discount', 'ListPrice', 'SaleswithStandard', 'NetSales',
#        'OrderQuantity', 'Sales'],
#       dtype='object')

# %%
df=df[['productcategory','saleterritory','Country','OrderCount','OrderDate','Sales','OrderQuantity','Discount']]

# %%
df.head()
# Out:
#   productcategory   saleterritory         Country  OrderCount  OrderDate  \
# 0        Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 1     Accessories  United Kingdom  United Kingdom           1 2012-06-30
# 2        Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 3        Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 4        Clothing  United Kingdom  United Kingdom           1 2012-06-30
#
#         Sales  OrderQuantity  Discount
# 0   68.786592             14    1.4038
# 1   90.000000              6    0.0000
# 2  182.352000              8    0.0000
# 3  317.596400             16   16.7156
# 4  159.558000              7    0.0000

# %%
df=df.rename(columns={'productcategory':'Category','saleterritory':'Territory','OrderQuantity':'Quantity','OrderDate':'Date'})

# %%
df.head(5)
# Out:
#       Category       Territory         Country  OrderCount       Date  \
# 0     Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 1  Accessories  United Kingdom  United Kingdom           1 2012-06-30
# 2     Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 3     Clothing  United Kingdom  United Kingdom           1 2012-06-30
# 4     Clothing  United Kingdom  United Kingdom           1 2012-06-30
#
#         Sales  Quantity  Discount
# 0   68.786592        14    1.4038
# 1   90.000000         6    0.0000
# 2  182.352000         8    0.0000
# 3  317.596400        16   16.7156
# 4  159.558000         7    0.0000

# %%
df.Quantity.unique()
# Out:
# array([14,  6,  8, 16,  7,  2,  1,  3,  4,  5, 10, 13, 12, 18, 15, 11,  9,
#        17, 23, 34, 19, 33, 24, 41, 38, 27, 26, 21, 20, 31, 25, 22, 32, 28,
#        29, 39, 44, 36, 40, 30, 35], dtype=int64)

# %%
df.Sales.unique()
# Out:
# array([  68.786592,   90.      ,  182.352   , ..., 2466.4185  ,
#         436.69505 ,   58.383   ])

# %%
df.shape
# Out:
# (60880, 8)

# %%
df[['Sales','Quantity']].describe()
# Out:
#               Sales      Quantity
# count  60880.000000  60880.000000
# mean    1322.071356      3.523587
# std     2124.171872      3.033950
# min        1.374000      1.000000
# 25%      127.800000      2.000000
# 50%      461.694000      3.000000
# 75%     1466.010000      4.000000
# max    27893.619000     44.000000

# %%
print("Mode of sales is :", df['Sales'].mode())
# Out:
# Mode of sales is : 0    419.4589
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['Sales'],hist=True)
# Out:
# D:\Code\ETL\ETL-Python-Scripts\etl_env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
# positive skew unimodal -> one peak

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(df['Sales'])
plt.show()

# %%
data=df['Sales']
mean,std=norm.fit(data)
plt.hist(data,bins=25,density=True)

xmin,xmax=plt.xlim()
x=np.linspace(xmin,xmax,100)
p=norm.pdf(x,mean,std)
plt.plot(x,p,'k',linewidth=2)
plt.show()

# %%
# outliers

# %%
sns.boxplot(df['Sales'])
# Out:
# D:\Code\ETL\ETL-Python-Scripts\etl_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %%
# remove outliers

# %%
Q1=df.Sales.quantile(0.25)
Q3=df.Sales.quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 127.8 1466.01 1338.21

# %%
# threshold
LTV=Q1-1.5*IQR
UTV=Q3+1.5*IQR
print(LTV,UTV)
# Out:
# -1879.515 3473.325

# %%
def removeOutliers(df):
    for i in df.describe().columns:
        Q1=df.describe().at['25%',i]
        Q3=df.describe().at['75%',i]
        IQR=Q3-Q1
        LTV=Q1-1.5*IQR
        UTV=Q3+1.5*IQR
        x=np.array(df[i])
        p=[]
        for j in x:
            if(j<LTV or j>UTV):
                p.append(df[i].median())
            else:
                p.append(j)
        df[i]=p
    return df

# %%
removeOutliers(df)
# Out:
#           Category       Territory         Country  OrderCount       Date  \
# 0         Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 1      Accessories  United Kingdom  United Kingdom         1.0 2012-06-30
# 2         Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 3         Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 4         Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# ...            ...             ...             ...         ...        ...
# 60875     Clothing       Southeast   United States         1.0 2014-05-01
# 60876     Clothing       Southeast   United States         1.0 2014-05-01
# 60877     Clothing       Southeast   United States         1.0 2014-05-01
# 60878     Clothing       Southeast   United States         1.0 2014-05-01
# 60879     Clothing       Southeast   United States         1.0 2014-05-01
#
#             Sales  Quantity  Discount
# 0       68.786592       3.0       0.0
# 1       90.000000       6.0       0.0
# 2      182.352000       3.0       0.0
# 3      317.596400       3.0       0.0
# 4      159.558000       7.0       0.0
# ...           ...       ...       ...
# 60875  335.952000       3.0       0.0
# 60876  251.964000       6.0       0.0
# 60877  125.982000       3.0       0.0
# 60878  209.970000       5.0       0.0
# 60879  125.982000       3.0       0.0
#
# [60880 rows x 8 columns]

# %%
sns.boxplot(df['Sales'])
# Out:
# D:\Code\ETL\ETL-Python-Scripts\etl_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %%
Q1=df.Sales.quantile(0.25)
Q3=df.Sales.quantile(0.75)
IQR=Q3-Q1
print(Q1,Q3,IQR)
# Out:
# 127.8 939.588 811.788

# %%
# drop duplicates
df=df.drop_duplicates()
df.head()
# Out:
#       Category       Territory         Country  OrderCount       Date  \
# 0     Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 1  Accessories  United Kingdom  United Kingdom         1.0 2012-06-30
# 2     Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 3     Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
# 4     Clothing  United Kingdom  United Kingdom         1.0 2012-06-30
#
#         Sales  Quantity  Discount
# 0   68.786592       3.0       0.0
# 1   90.000000       6.0       0.0
# 2  182.352000       3.0       0.0
# 3  317.596400       3.0       0.0
# 4  159.558000       7.0       0.0

# %%
df.count()
# Out:
# Category      29543
# Territory     29580
# Country       29580
# OrderCount    29580
# Date          29580
# Sales         29580
# Quantity      29580
# Discount      29580
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Category      37
# Territory      0
# Country        0
# OrderCount     0
# Date           0
# Sales          0
# Quantity       0
# Discount       0
# dtype: int64

# %%
# drop null
df=df.dropna()
df.count()
# Out:
# Category      29543
# Territory     29543
# Country       29543
# OrderCount    29543
# Date          29543
# Sales         29543
# Quantity      29543
# Discount      29543
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Category      0
# Territory     0
# Country       0
# OrderCount    0
# Date          0
# Sales         0
# Quantity      0
# Discount      0
# dtype: int64

# %%
# univariate analysis -> analysis of a single variable(column)

# %%
df.Category.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.Category.value_counts()
# Out:
# Components     11268
# Clothing        7733
# Bikes           7048
# Accessories     3494
# Name: Category, dtype: int64

# %%
# get frequency
tab=pd.crosstab(index=df['Category'],columns=['Relative Frequency'])
print(tab)
# Out:
# col_0        Relative Frequency
# Category
# Accessories                3494
# Bikes                      7048
# Clothing                   7733
# Components                11268

# %%
print(tab/tab.sum())
# Out:
# col_0        Relative Frequency
# Category
# Accessories            0.118268
# Bikes                  0.238568
# Clothing               0.261754
# Components             0.381410

# %%
# https://youtu.be/y4S2gNbl9Ec?t=1279
